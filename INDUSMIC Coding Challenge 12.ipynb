# %%
##CODING CHALLENGE 12

#import all the required libraries
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
#Ques 1:

def f(x1,x2):
    y=0;
    for j in range(1,6):
        y=y+j*np.cos((j+1)*x1+j)+ j*np.cos((j+1)*x2+j)
    return y

x1=np.linspace(-10,10,20)
x2=np.linspace(-10,10,20)

X1,X2=np.meshgrid(x1,x2)
Z=f(X1,X2)

fig=plt.figure()
ax=plt.axes(projection='3d')
ax.plot_surface(X1,X2,Z,cmap=cm.coolwarm)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('fx')
ax.set_title('Ques1')
# Out:
# Text(0.5, 0.92, 'Ques1')

# %%
#Ques 2:

def f(x1,x2):
    return np.random.random(1)*pow(abs(x1),1) + np.random.random(1)*pow(abs(x2),2)

x1=np.linspace(-5,5,10)
x2=np.linspace(-5,5,10)

X1,X2=np.meshgrid(x1,x2)
Z=f(X1,X2)

fig=plt.figure()
ax=plt.axes(projection='3d')
ax.plot_surface(X1,X2,Z,cmap=cm.coolwarm)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('fx')
ax.set_title('Ques2')
# Out:
# Text(0.5, 0.92, 'Ques2')

# %%
#Ques 3:

def f(x1,x2):
    return (np.sin(x1)*np.sin(x1)+np.sin(x2)*np.sin(x2)-np.exp(-(x1**2+x2**2)))*np.exp(-((pow(np.sin(np.sqrt(abs(x1))),2)))+pow(np.sin(np.sqrt(abs(x2))),2))

x1=np.linspace(-10,10,30)
x2=np.linspace(-10,10,30)

X1,X2=np.meshgrid(x1,x2)
Z=f(X1,X2)

fig=plt.figure()
ax=plt.axes(projection='3d')
ax.plot_surface(X1,X2,Z,cmap=cm.coolwarm)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('fx')
ax.set_title('Ques3')
# Out:
# Text(0.5, 0.92, 'Ques3')

# %%
#Ques 4:

def f(x,y):
    return abs(x**2+y**2+x*y)+abs(np.sin(x))+abs(np.cos(y))

x=np.linspace(-500,500,1000)
y=np.linspace(-500,500,1000)

X,Y=np.meshgrid(x,y)
Z=f(X,Y)

fig=plt.figure()
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap=cm.coolwarm)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('fx')
ax.set_title('Ques4')
# Out:
# Text(0.5, 0.92, 'Ques4')

# %%
#Ques 5:

def f(x,y):
    return (x+10)**2+(y+10)**2+np.exp(-x**2-y**2);

x=np.linspace(-20,0,20)
y=np.linspace(-20,0,20)

X,Y=np.meshgrid(x,y)
Z=f(X,Y)

fig=plt.figure()
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap=cm.coolwarm)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('fx')
ax.set_title('Ques5')
# Out:
# Text(0.5, 0.92, 'Ques5')

# %%
system("jupyter" "notebook" "list")
# Out:
# ['Currently running servers:',
#  'http://localhost:8888/?token=185805a8502ea33c624eaa437073002ca7b5136da7d70fe2 :: C:\\Users\\shivangi dubey']
